# %% [markdown]
# # Input and Output operations for various formats like csv and excel

# %%
import numpy as np
import pandas as pd

# %%
pwd
# Out:
# '/home/thunder_07/Desktop/ML course'

# %%
df= pd.read_csv("example")
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv("new")
pd.read_csv("new")
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df.to_csv("new2",index=False)
pd.read_csv("new2")
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
pd.read_excel("Excel_Sample.xlsx",sheet_name="Sheet1")
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
import requests

url = 'https://www.worldcoinindex.com/'

cryptoUrl = requests.get(url)
cryptoUrl
# Out:
# <Response [200]>

# %%
crypto_data=pd.read_html(cryptoUrl.text)
crypto_data[0]
# Out:
#        # Unnamed: 1               Name Ticker  Last price        %  \
# 0      1        NaN            Bitcoin    BTC    $ 40,925   +0.24%
# 1      2        NaN           Ethereum    ETH  $ 3,058.41   -0.01%
# 2      3        NaN              STEPN    GMT      $ 3.29   +2.63%
# 3      4        NaN              Terra   LUNA     $ 90.87   -0.23%
# 4      5        NaN      NEAR Protocol   NEAR     $ 17.09   +5.38%
# ..   ...        ...                ...    ...         ...      ...
# 97    96        NaN    Mirror Protocol    MIR      $ 1.47   +1.09%
# 98    97        NaN  Alpha Quark Token    AQT      $ 3.05  +11.64%
# 99    98        NaN                Ren    REN  $ 0.365474   +2.61%
# 100   99        NaN            Trueusd   TUSD  $ 0.998659   -0.26%
# 101  100        NaN                Bat    BAT  $ 0.755379   -1.09%
#
#         24 high      24 low Price Charts 7d 24 volume  # Coins Market cap
# 0      $ 41,220    $ 40,625             NaN  $ 10.51B   19.01M  $ 778.22B
# ...

# %%
crypto_data[0].iloc[:,2:]
# Out:
#                   Name Ticker  Last price        %     24 high      24 low  \
# 0              Bitcoin    BTC    $ 40,925   +0.24%    $ 41,220    $ 40,625
# 1             Ethereum    ETH  $ 3,058.41   -0.01%  $ 3,089.86  $ 3,035.47
# 2                STEPN    GMT      $ 3.29   +2.63%      $ 3.43      $ 3.15
# 3                Terra   LUNA     $ 90.87   -0.23%     $ 91.83     $ 88.57
# 4        NEAR Protocol   NEAR     $ 17.09   +5.38%     $ 17.18     $ 16.18
# ..                 ...    ...         ...      ...         ...         ...
# 97     Mirror Protocol    MIR      $ 1.47   +1.09%      $ 1.48      $ 1.44
# 98   Alpha Quark Token    AQT      $ 3.05  +11.64%      $ 3.11      $ 2.69
# 99                 Ren    REN  $ 0.365474   +2.61%  $ 0.371685  $ 0.347531
# 100            Trueusd   TUSD  $ 0.998659   -0.26%      $ 1.00  $ 0.997561
# 101                Bat    BAT  $ 0.755379   -1.09%  $ 0.768102  $ 0.745372
#
#     Price Charts 7d 24 volume  # Coins Market cap
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine("sqlite:///:memory:")

df.to_sql("MY_sql",engine)

# %%
pd.read_sql("MY_sql",con=engine)
# Out:
#    index   a   b   c   d
# 0      0   0   1   2   3
# 1      1   4   5   6   7
# 2      2   8   9  10  11
# 3      3  12  13  14  15
